# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\itay\Desktop\Salary Data.csv')
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
df_Grp_Exp = df.groupby('Years of Experience')['Salary'].agg('mean').reset_index()
df_Grp_Exp
# Out:
#     Years of Experience         Salary
# 0                   0.0   33333.333333
# 1                   0.5   35000.000000
# 2                   1.0   37857.142857
# 3                   1.5   36279.166667
# 4                   2.0   41774.193548
# 5                   3.0   51166.666667
# 6                   4.0   58500.000000
# 7                   5.0   64117.647059
# 8                   6.0   83750.000000
# 9                   7.0   84444.444444
# 10                  8.0   88800.000000
# 11                  9.0  101818.181818
# 12                 10.0  100555.555556
# 13                 11.0  100500.000000
# 14                 12.0  105000.000000
# 15                 13.0  120000.000000
# 16                 14.0  125769.230769
# 17                 15.0  134375.000000
# 18                 16.0  157500.000000
# 19                 17.0  143000.000000
# 20                 18.0  149615.384615
# 21                 19.0  166333.333333
# 22                 20.0  168846.153846
# ...

# %%
df_Grp_Exp['Salary'] = df_Grp_Exp['Salary'].round(2)
df_Grp_Exp
# Out:
#     Years of Experience     Salary
# 0                   0.0   33333.33
# 1                   0.5   35000.00
# 2                   1.0   37857.14
# 3                   1.5   36279.17
# 4                   2.0   41774.19
# 5                   3.0   51166.67
# 6                   4.0   58500.00
# 7                   5.0   64117.65
# 8                   6.0   83750.00
# 9                   7.0   84444.44
# 10                  8.0   88800.00
# 11                  9.0  101818.18
# 12                 10.0  100555.56
# 13                 11.0  100500.00
# 14                 12.0  105000.00
# 15                 13.0  120000.00
# 16                 14.0  125769.23
# 17                 15.0  134375.00
# 18                 16.0  157500.00
# 19                 17.0  143000.00
# 20                 18.0  149615.38
# 21                 19.0  166333.33
# 22                 20.0  168846.15
# 23                 21.0  173846.15
# 24                 22.0  162222.22
# 25                 23.0  177500.00
# ...

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_Grp_Exp.index, df_Grp_Exp['Salary'], marker='o', linestyle='-', color='b', label='Salary')
plt.title('Years of expirience - Salary')
plt.xlabel('Years of expirience')
plt.ylabel('Salary')
plt.legend()
plt.grid(True)
plt.show()

# %%
df_Grp_Title = df.groupby('Job Title')['Salary'].agg('mean').reset_index()
df_Grp_Title
# Out:
#                         Job Title    Salary
# 0                 Account Manager   75000.0
# 1                      Accountant   55000.0
# 2        Administrative Assistant   50000.0
# 3                Business Analyst   77500.0
# 4    Business Development Manager   90000.0
# ..                            ...       ...
# 169                   UX Designer   80000.0
# 170                 UX Researcher   65000.0
# 171                 VP of Finance  200000.0
# 172              VP of Operations  190000.0
# 173                 Web Developer   65000.0
#
# [174 rows x 2 columns]

# %%
plt.figure(figsize=(12,6))
plt.bar(df_Grp_Title['Job Title'], df_Grp_Title['Salary'], color='skyblue')
plt.xlabel('Job Title')
plt.ylabel('Average Salary')
plt.title('Average Salary per Job Title')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
df_Grp_Age = df.groupby('Age')['Salary'].agg('mean').reset_index()
df_Grp_Age['Salary'] = df_Grp_Age['Salary'].round(2)
df_Grp_Age
# Out:
#      Age     Salary
# 0   23.0   35000.00
# 1   24.0   40000.00
# 2   25.0   35000.00
# 3   26.0   39285.71
# 4   27.0   44444.44
# 5   28.0   41538.46
# 6   29.0   42841.30
# 7   30.0   46666.67
# 8   31.0   54285.71
# 9   32.0   66666.67
# 10  33.0   70625.00
# 11  34.0   90000.00
# 12  35.0   89772.73
# 13  36.0   87000.00
# 14  37.0  103750.00
# 15  38.0  104000.00
# 16  39.0   92916.67
# 17  40.0  103076.92
# 18  41.0  118333.33
# 19  42.0  124090.91
# 20  43.0  141250.00
# 21  44.0  146666.67
# 22  45.0  153529.41
# 23  46.0  151500.00
# 24  47.0  171666.67
# 25  48.0  173888.89
# 26  49.0  170000.00
# 27  50.0  177500.00
# 28  51.0  171000.00
# 29  52.0  206666.67
# 30  53.0  180000.00

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_Grp_Age['Age'], df_Grp_Age['Salary'], marker='o', linestyle='-', color='b', label='Salary')
plt.title('Age - Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.legend()
plt.grid(True)
plt.show()

# %%
# plotting heatmap with correlations between the features 
plt.figure(figsize=(10,8))
sns.heatmap(train_data.drop('ocean_proximity',axis=1).corr(), annot=True, cmap='YlGnBu')

# %%
df_numeric = df
df_numeric['Gender'].replace('Female', False, inplace=True)
df_numeric['Gender'].replace('Male', True, inplace=True)
df_numeric['Education Level'].replace("Bachelor's", 0, inplace=True)
df_numeric['Education Level'].replace("Master's", 1, inplace=True)
df_numeric['Education Level'].replace("PhD", 2, inplace=True)
df_numeric
# Out:
#       Age  Gender  Education Level                      Job Title  \
# 0    32.0     1.0              0.0              Software Engineer
# 1    28.0     0.0              1.0                   Data Analyst
# 2    45.0     1.0              2.0                 Senior Manager
# 3    36.0     0.0              0.0                Sales Associate
# 4    52.0     1.0              1.0                       Director
# ..    ...     ...              ...                            ...
# 370  35.0     0.0              0.0       Senior Marketing Analyst
# 371  43.0     1.0              1.0         Director of Operations
# 372  29.0     0.0              0.0         Junior Project Manager
# 373  34.0     1.0              0.0  Senior Operations Coordinator
# 374  44.0     0.0              2.0        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df_numeric.drop('Job Title', axis=1).corr(), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
# fit a linear regrresion model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df_model = df.drop('Job Title', axis=1)
df_model
# Out:
#       Age  Gender  Education Level  Years of Experience    Salary
# 0    32.0     1.0              0.0                  5.0   90000.0
# 1    28.0     0.0              1.0                  3.0   65000.0
# 2    45.0     1.0              2.0                 15.0  150000.0
# 3    36.0     0.0              0.0                  7.0   60000.0
# 4    52.0     1.0              1.0                 20.0  200000.0
# ..    ...     ...              ...                  ...       ...
# 370  35.0     0.0              0.0                  8.0   85000.0
# 371  43.0     1.0              1.0                 19.0  170000.0
# 372  29.0     0.0              0.0                  2.0   40000.0
# 373  34.0     1.0              0.0                  7.0   90000.0
# 374  44.0     0.0              2.0                 15.0  150000.0
#
# [375 rows x 5 columns]

# %%
df_model.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Gender'}>],
#        [<Axes: title={'center': 'Education Level'}>,
#         <Axes: title={'center': 'Years of Experience'}>],
#        [<Axes: title={'center': 'Salary'}>, <Axes: >]], dtype=object)

# %%
log_transform_features = ['Age', 'Gender', 'Education Level', 'Years of Experience']

for feature in log_transform_features:
    df_model[feature] = np.log(df_model[feature] + 1)
    
df_model.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Gender'}>],
#        [<Axes: title={'center': 'Education Level'}>,
#         <Axes: title={'center': 'Years of Experience'}>],
#        [<Axes: title={'center': 'Salary'}>, <Axes: >]], dtype=object)

# %%
df_model.dropna(inplace=True)
df_model
# Out:
#           Age    Gender  Education Level  Years of Experience    Salary
# 0    3.496508  0.693147         0.000000             1.791759   90000.0
# 1    3.367296  0.000000         0.693147             1.386294   65000.0
# 2    3.828641  0.693147         1.098612             2.772589  150000.0
# 3    3.610918  0.000000         0.000000             2.079442   60000.0
# 4    3.970292  0.693147         0.693147             3.044522  200000.0
# ..        ...       ...              ...                  ...       ...
# 370  3.583519  0.000000         0.000000             2.197225   85000.0
# 371  3.784190  0.693147         0.693147             2.995732  170000.0
# 372  3.401197  0.000000         0.000000             1.098612   40000.0
# 373  3.555348  0.693147         0.000000             2.079442   90000.0
# 374  3.806662  0.000000         1.098612             2.772589  150000.0
#
# [373 rows x 5 columns]

# %%
X = df_model.drop(['Salary'], axis=1)
y = df_model['Salary']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
train_data = X_train.join(y_train)
test_data = X_test.join(y_test)

X_train, y_train = train_data.drop(['Salary'], axis=1), train_data['Salary']
x_test, y_test = test_data.drop(['Salary'], axis=1), test_data['Salary']

reg = LinearRegression()
reg.fit(X_train, y_train)

reg.score(x_test, y_test)
# Out:
# 0.8987393096304367
